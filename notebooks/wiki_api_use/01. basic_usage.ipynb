# %%
import wikipediaapi

# %% [markdown]
# # 1. Getting Single Page

# %%
wiki_wiki = wikipediaapi.Wikipedia(user_agent='MyProjectName (merlin@example.com)', language='en')

page_py = wiki_wiki.page('India')

# %%
## checking if page exists
page_py.exists()
# Out:
# True

# %%
## page url
### full url
print(page_py.fullurl)
# Out:
# https://en.wikipedia.org/wiki/India

# %%
## page url
### canonical url
print(page_py.canonicalurl)
# Out:
# https://en.wikipedia.org/wiki/India

# %% [markdown]
# ## 1.2. Page Metadta

# %%
## title
print(page_py.title)
# Out:
# 'India'

# %%
## summary
print(page_py.summary)
# Out:
# India, officially the Republic of India, is a country in South Asia.  It is the seventh-largest country by area; the most populous country since 2023; and, since its independence in 1947, the world's most populous democracy. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west; China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia.
# ...

# %% [markdown]
# ## 1.3. Getting Full Text

# %%
## plain text
print(page_py.text)
# Out:
# India, officially the Republic of India, is a country in South Asia.  It is the seventh-largest country by area; the most populous country since 2023; and, since its independence in 1947, the world's most populous democracy. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west; China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia.
# ...

# %%
## as in html
wiki_html = wikipediaapi.Wikipedia(
    user_agent='MyProjectName (merlin@example.com)',
    language='en',
    extract_format=wikipediaapi.ExtractFormat.HTML
)
p_html = wiki_html.page("India")
print(p_html.text)
# Out:
# <p class="mw-empty-elt">
#
#
#
#
# </p>
#
# <p><b>India</b>, officially the <b>Republic of India</b>, is a country in South Asia.  It is the seventh-largest country by area; the most populous country since 2023; and, since its independence in 1947, the world's most populous democracy. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west; China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia.
# ...

# %%
## getting sections
def print_sections(sections, level=0):
    for s in sections:
        print("%s: %s - %s" % ("*" * (level + 1), s.title, s.text[0:40]))
        print_sections(s.sections, level + 1)

# %%
print_sections(page_py.sections)
# Out:
# *: Etymology - According to the Oxford English Dictiona
# *: History -
# **: Ancient India - By 55,000 years ago, the first modern hu
# **: Medieval India - The Indian early medieval age, from 600
# **: Early modern India - In the early 16th century, northern Indi
# **: Modern India - Historians consider India's modern age t
# *: Geography - India accounts for the bulk of the India
# **: Biodiversity - India is a megadiverse country, a term e
# *: Politics and government -
# **: Politics - India is a parliamentary republic with a
# **: Government - India is a federation with a parliamenta
# **: Administrative divisions - India is a federal union comprising 28 s
# ***: States -
# ***: Union territories -
# *: Foreign, economic, and strategic relations - India became a republic in 1950, remaini
# *: Economy - According to the International Monetary
# **: Industries - The Indian automotive industry, the worl
# **: Energy - India's capacity to generate electrical
# ...

# %% [markdown]
# ## 1.4. Getting in Different languages

# %%
def print_langlinks(page):
    langlinks = page.langlinks
    for k in sorted(langlinks.keys()):
        v = langlinks[k]
        print("%s: %s - %s: %s" % (k, v.language, v.title, v.fullurl))

# %%
print_langlinks(page_py)
# Out:
# ab: ab - Индиа: https://ab.wikipedia.org/wiki/%D0%98%D0%BD%D0%B4%D0%B8%D0%B0
# ace: ace - India: https://ace.wikipedia.org/wiki/India
# ady: ady - Индие: https://ady.wikipedia.org/wiki/%D0%98%D0%BD%D0%B4%D0%B8%D0%B5
# af: af - Indië: https://af.wikipedia.org/wiki/Indi%C3%AB
# am: am - ህንድ: https://am.wikipedia.org/wiki/%E1%88%85%E1%8A%95%E1%8B%B5
# ami: ami - India: https://ami.wikipedia.org/wiki/India
# an: an - India: https://an.wikipedia.org/wiki/India
# ang: ang - Indea: https://ang.wikipedia.org/wiki/Indea
# ann: ann - India: https://ann.wikipedia.org/wiki/India
# anp: anp - भारत: https://anp.wikipedia.org/wiki/%E0%A4%AD%E0%A4%BE%E0%A4%B0%E0%A4%A4
# ar: ar - الهند: https://ar.wikipedia.org/wiki/%D8%A7%D9%84%D9%87%D9%86%D8%AF
# arc: arc - ܗܢܕܘ: https://arc.wikipedia.org/wiki/%DC%97%DC%A2%DC%95%DC%98
# ary: ary - لهند: https://ary.wikipedia.org/wiki/%D9%84%D9%87%D9%86%D8%AF
# arz: arz - الهند: https://arz.wikipedia.org/wiki/%D8%A7%D9%84%D9%87%D9%86%D8%AF
# ...

# %% [markdown]
# [Wiki Media Analytics](https://doc.wikimedia.org/generated-data-platform/aqs/analytics-api/documentation/getting-started.html)
