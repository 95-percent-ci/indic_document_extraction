# %% [markdown]
# ## 1. Output Schema
#
# `OCRResult` Object is returned, which is form a Pydantic Object. This object has two keys
#
# * `text_lines` : Contains list of `text_line` objects
# * `image_bbox`
#
# ## 1.1. text_lines
# It contains list of `text_line` object.
#
# ### 1.1.1. text_line
# Each `text-line` object capture, single distinct line of text as found by the OCR engine and it has following property
#
#  * `polygon`: This attribute defines the precise boundary of the text line using a set of four coordinate points, representing the corners of a polygon that encloses the text. This is particularly useful for text on a skewed or irregular baseline.
#
#  * `confidence`: This floating-point number, ranging from 0 to 1, indicates the model's confidence in the accuracy of the recognized text for that entire line. A higher value signifies a greater level of certainty.
#  * `text`: This is a string containing the actual text that has been recognized from the line in the document.
#  * `bbox`: This provides the bounding box of the text line as a set of four coordinates [x_min, y_min, x_max, y_max]. It represents the smallest rectangle that encloses the text line.
#  * `chars`: This is a list of `TextChar` objects, breaking down the recognized line into its individual characters.
#      > Similar to `text-line` it also has `polygon`, `confidence`, `text`, `bbox`, `bbox-valid` properties
