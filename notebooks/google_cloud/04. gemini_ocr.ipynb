# %%
import vertexai
from vertexai.generative_models import GenerativeModel, Part
import os
from google import genai
from google.genai.types import (
    Part,
    )

# %%
from google.genai import types

# %%
from dotenv import load_dotenv

# %%
PROJECT_ID = os.getenv("PROJECT_ID", "")
LOCATION = "us-east1"

# %%
client = genai.Client(vertexai=True, project=PROJECT_ID, location=LOCATION)
MODEL_ID = "gemini-2.5-pro"

# %%
# Read the image data
file_path = "/Users/niteshkumarsharma/Desktop/Folder/AI/indic_document_extraction/synth_data/santali/images/level_0/Ol-chiki_Noto_Sans_Ol_Chiki_2_n_pages_1_1.png"
# Read the file into memory.
with open(file_path, "rb") as image:
    image_bytes = image.read()

# Initialize Vertex AI
vertexai.init(project=PROJECT_ID, location=LOCATION)
# Load the model
multimodal_model = GenerativeModel(MODEL_ID)
# Prepare the generation configuration
generation_config = {
    "max_output_tokens": 8192,
    "temperature": 1,
    "top_p": 0.95,
}

response = client.models.generate_content(
    model='gemini-2.5-pro',
    contents=[      
        'Perform OCR, language is manipuri',
        types.Part.from_bytes(data=image_bytes, mime_type='image/png'),
    ],
)
# Out:
# /Users/niteshkumarsharma/Desktop/Folder/AI/indic_document_extraction/.venv/lib/python3.11/site-packages/vertexai/generative_models/_generative_models.py:433: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()

# %%
response.text
# Out:
# "MN.107 KDOMNWISTWA KHADANGGED NA DE\n\nKHADANGGED NOWN' PO CONVE DEENG UND LOWED NA UNCSBEAKADAMPANA BAEA,\nLOUD PO CONUT DEENG OZKMA UNANG KOWDA NA OZKMA UNANG UDNAODOPANDE\nNANAN BAEA (IMK2 K2'DEK KAU UZKA BMO2) NA DAGMPZED BMVBENA DEENG\nZDUAZAKHADNAMDA OMPUN BAEA, I EDUN UNCSBEAKADAMPANA PO CONOZ DE UBLENG\nNOOD BADE NA.KON WOA 2P NE BAEN, I EDUN PO 200U-IMA2 CONOZ DEENG\nKHADANGGED DEZAEKBPA DE UZENG-N, I KHADANGGED PO CCEG KMP2 DE ODAG\nDDIWAKAEMP OSMADE KZDUA PZBMO2 WNOMAN, NAWA' KZDUM DE KHADANGGED\nKDONWISTWA DEENG BAN O2 DEZNU NIBNE DANG BAEA, NAWA' PO KBD9B6A97O\nUZENG-N NA EDUN PO KOWOD DEENG BMPEMDAP WEDANEND DEENG WA.NAQ\nPZBSO2 UMEMU OMONU UZENG-N, I EDUN BAN.O7D O2 KOWOD OMPUN NA DA7OAN\nKOWOD PO UAD W5MAQ KOWOD PZBN N.CBN.V BAEN, NAWA' DE DAZEMA DANG\nDEENG 2PZP N.O7 NA.KOA G2 UZENG-N, NA EDUN PO GAZHNA KHADANGGED\nDEENG KM:GAQ NANAN DE KOWOD DEENG WOA 2P MN.107 DE GOID ZU NBA9N I\n\n20 KDONWISTWA DEENG U5AN.9 K2P KOWOD DEENG WOA 2P PO N.07 PAGDE\nMN.107 ZEM, DEENG 
# ...
