# %% [markdown]
# # 1. Context
#
# This notebook illustrates noise augmentatiom over pdf images

# %% [markdown]
# # 2. Imports

# %%
from pathlib import Path
import sys

# %%
notebook_path = Path().resolve()
project_root = notebook_path.parents[1] 
sys.path.append(str(project_root))

# %%
from src.augmentation.noise_addition import augment_image
from src.augmentation.utils import pdf_to_images

# %% [markdown]
# # 3. Augmentation Flow

# %% [markdown]
# ## 3.1. PDF to Images

# %%
_PDF_PATH_ = "sample.pdf"
output_dir = "output/clean"
doc_id = "sample_output"

# %%
pdf_to_images(_PDF_PATH_, doc_id, output_dir)

# %% [markdown]
# ## 3.2. Noise Addition

# %%
_IMG_PATH_ = "output/clean/sample_output_1.png" 
output_dir = "output/augmented"

# %%
augment_image(_IMG_PATH_, output_dir)
