# %% [markdown]
# # 1. Context
#
# This notebook illustrates usage for synthethic pdf dataset generation

# %% [markdown]
# # 2. Imports

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
from pathlib import Path, PosixPath
import sys

# %%
from pathlib import Path

# %%
notebook_path = Path().resolve()
project_root = notebook_path.parents[1] 
sys.path.append(str(project_root))

# %%
from src.data_generation.pdf_generation_ import IndicPDFGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from src.data_generation.pdf_generation_v2 import IndicPDFGenerator
#
# File ~/Desktop/Folder/AI/indic_document_extraction/src/data_generation/pdf_generation_v2.py:5
#       3 from fpdf import FPDF
#       4 from fpdf.enums import Align
# ----> 5 from fpdf.context import DryRun
#       7 class PDF(FPDF):
#       8     """Custom PDF Class to manage headers, body & footers"""
#
# ModuleNotFoundError: No module named 'fpdf.context'

# %% [markdown]
# # 3. Font and Sample Text
#
# - Text: Text to be generated
# - Font: Font Files for Normal, Bold & Italic
#
# Text can be replaced with Sources of error free texts like Wikipedia etc, while Font can fetched via Google Fonts API

# %%
text_sample = """ਮਹਿੰਦਰਗੜ੍ਹ ਜ਼ਿਲਾ ਭਾਰਤ ਦੇ ਹਰਿਆਣਾ ਰਾਜ ਦਾ ਜ਼ਿਲਾ ਹੈ। ਇਹ ਜ਼ਿਲਾ 1,859 ਕਿਲੋਮੀਟਰ2 ਵੱਡਾ ਹੈ। ਇਸ ਜ਼ਿਲੇ ਦੀ ਜਨਸੰਖਿਆ 812,022 (2001 ਸੇਂਸਸ ਮੁਤਾਬਕ) ਹੈ। ਇਹ ਜ਼ਿਲਾ 1 ਨਵੰਬਰ 1948 ਨੂੰ ਬਣਾਇਆ ਗਿਆ ਸੀ ਅਤੇ ਬਾਅਦ ਵਿੱਚ ਪਟਿਆਲਾ ਅਤੇ ਪੰਜਾਬ ਨੂੰ ਇਕੱਠਾ ਕਰਨ ਬਾਅਦ ਇਹ ਜ਼ਿਲਾ ਪੰਜਾਬ ਵਿੱਚ ਆ ਗਿਆ। 1966 ਨੂੰ ਹਰਿਆਣਾ ਰਾਜ ਬਨਣ ਬਾਅਦ ਇਹ ਜ਼ਿਲਾ ਹਰਿਆਣੇ ਵਿੱਚ ਆ ਗਿਆ। 1989 ਨੂੰ ਇਸ ਵਿੱਚੋਂ ਰੇਵਾੜੀ ਬਣਾਇਆ ਗਿਆ ਸੀ। """

# %%
text_mni = """ꯀꯣꯔꯤꯌꯥ ꯍꯥꯏꯕꯁꯤ ꯅꯣꯡꯄꯣꯛ ꯑꯦꯁꯤꯌꯥ ꯃꯅꯨꯡꯗ ꯂꯩꯩꯩꯩꯕꯥ ꯂꯝꯗꯝ ꯑꯃꯅꯤ ꯫ ꯀꯨꯝꯖꯥ ꯱꯹꯴꯸ ꯇꯥꯒꯤ ꯍꯧꯔꯒ ꯑꯋꯥꯡ ꯀꯣꯔꯤꯌꯥ ꯑꯃꯁꯨ�
इससे पहले चंद्रमा के दक्षिणी ध्रुव पर एक अभियान की जापान के साथ सहयोग के बारे में खबरें सामने आई थीं, जहां भारत लैंडर प्रदान करता जबकि जापान प्रक्षेपक और रोवर दोनों प्रदान करने वाला था। अभियान में स्थान से नमूने लेना और चंद्रमा पर रात के समय जीवित रहने की तकनीक शामिल करने की भी संभावनाएँ थीं।[15] [16]

विक्रम लैंडर की बाद की विफलता के कारण 2025 के लिए जापान के साथ साझेदारी में प्रस्तावित चंद्र ध्रुवीय खोजबीन मिशन (LUPEX) के लिए आवश्यक लैंडिंग क्षमताओं को प्रदर्शित करने के लिए एक और अभियान (चंद्रयान-3) करने का प्रस्ताव दिया गया।[17] मिशन के महत्वपूर्ण फ्लाइट ऑपरेशन के दौरान, यूरोपीय अंतरिक्ष एजेंसी (ईएसए) द्वारा संचालित यूरोपीय अंतरिक्ष ट्रैकिंग (एस्ट्रैक) एक अनुबंध के अंतर्गत इस मिशन को सपोर्ट प्रदान करेगी।[18]

चंद्रयान-3 को 14 जुलाई 2023 शुक्रवार को आंध्र प्रदेश के श्रीहरिकोटा स्थित सतीश धवन अंतरिक्ष केंद्र से दोपहर 2:35 मिनट पर प्रक्षेपित किया गया। 
"""

# %%
font_map_file = {
    'Noto_Sans': {
        'B': PosixPath('/Users/niteshkumarsharma/Desktop/Folder/AI/indic_document_extraction/fonts/Devanagari/Poppins/Poppins-700.ttf'), 
        'I': PosixPath('/Users/niteshkumarsharma/Desktop/Folder/AI/indic_document_extraction/fonts/Devanagari/Poppins/Poppins-italic.ttf'), 
        'BI': PosixPath('/Users/niteshkumarsharma/Desktop/Folder/AI/indic_document_extraction/fonts/Devanagari/Poppins/Poppins-700italic.ttf'),
        'normal': PosixPath('/Users/niteshkumarsharma/Desktop/Folder/AI/indic_document_extraction/fonts/Devanagari/Poppins/Poppins-regular.ttf')}}

# %%
path_normal = "/Users/niteshkumarsharma/Desktop/Folder/AI/indic_document_extraction/fonts/Meetei-mayek/Noto_Sans_Meetei_Mayek/Noto_Sans_Meetei_Mayek-regular.ttf"
path_bold = "/Users/niteshkumarsharma/Desktop/Folder/AI/indic_document_extraction/fonts/Meetei-mayek/Noto_Sans_Meetei_Mayek/Noto_Sans_Meetei_Mayek-700.ttf"

font_file_map = {
    "Kalam": {
        "normal": Path(path_normal),
        "B": Path(path_bold),
    }
}

# %% [markdown]
# # 4. Creation

# %%
pdf_generator = IndicPDFGenerator("Noto_Sans", font_map_file)
vv = pdf_generator.generate(text_hn * 10, "sample.pdf", )

# %%
pdf_obj = pdf_generator.pdf

# %%
pdf_obj.font_style

# %%
pdf_obj.set_font("noto_sans", style="B")
